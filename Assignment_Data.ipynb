# %%
import pandas as pd
import numpy as np

# %%
Assignment_Data_df = pd.read_csv(r'C:\Users\user\Desktop\Assignment_Data\Assignment-2_Data.csv')

# %%
Assignment_Data_df
# Out:
#           Id   age           job   marital  education default  balance  \
# 0       1001   NaN    management   married   tertiary      no   2143.0
# 1       1002   NaN           NaN    single  secondary      no     29.0
# 2       1003   NaN  entrepreneur   married  secondary      no      2.0
# 3       1004  47.0   blue-collar   married    unknown      no   1506.0
# 4       1005  33.0       unknown    single    unknown      no      1.0
# ...      ...   ...           ...       ...        ...     ...      ...
# 45206  46207  51.0    technician   married   tertiary      no    825.0
# 45207  46208  71.0       retired  divorced    primary      no   1729.0
# 45208  46209  72.0       retired   married  secondary      no   5715.0
# 45209  46210  57.0   blue-collar   married  secondary      no    668.0
# 45210  46211  37.0  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
Assignment_Data_df.head()
# Out:
#      Id   age           job  marital  education default  balance housing loan  \
# 0  1001   NaN    management  married   tertiary      no   2143.0     yes   no
# 1  1002   NaN           NaN   single  secondary      no     29.0     yes   no
# 2  1003   NaN  entrepreneur  married  secondary      no      2.0     yes  yes
# 3  1004  47.0   blue-collar  married    unknown      no   1506.0     yes   no
# 4  1005  33.0       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
Assignment_Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         45211 non-null  int64
#  1   age        45199 non-null  float64
#  2   job        45210 non-null  object
#  3   marital    45211 non-null  object
#  4   education  45211 non-null  object
#  5   default    45211 non-null  object
#  6   balance    45208 non-null  float64
#  7   housing    45211 non-null  object
#  8   loan       45211 non-null  object
#  9   contact    45211 non-null  object
#  10  day        45211 non-null  int64
#  11  month      45211 non-null  object
#  12  duration   45211 non-null  int64
#  13  campaign   45211 non-null  int64
#  14  pdays      45211 non-null  int64
#  15  previous   45211 non-null  int64
#  16  poutcome   45211 non-null  object
#  17  y          45211 non-null  object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 6.2+ MB

# %%
Assignment_Data_df.describe()
# Out:
#                  Id           age        balance           day      duration  \
# count  45211.000000  45199.000000   45208.000000  45211.000000  45211.000000
# mean   23606.000000     40.933627    1362.346620     15.806419    258.163080
# std    13051.435847     10.623149    3044.852387      8.322476    257.527812
# min     1001.000000     -1.000000   -8019.000000      1.000000      0.000000
# 25%    12303.500000     33.000000      72.000000      8.000000    103.000000
# 50%    23606.000000     39.000000     448.000000     16.000000    180.000000
# 75%    34908.500000     48.000000    1428.000000     21.000000    319.000000
# max    46211.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
Assignment_Data_df.isnull().sum()
# Out:
# Id            0
# age          12
# job           1
# marital       0
# education     0
# default       0
# balance       3
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# y             0
# dtype: int64

# %%
# Data Cleaning Steps

# 1. Handling NaN values: Fill numerical NaNs with median and categorical NaNs with 'unknown'
Assignment_Data_df['age'].fillna(Assignment_Data_df['age'].median(), inplace=True)
Assignment_Data_df['job'].fillna('unknown', inplace=True)
Assignment_Data_df['balance'].fillna(Assignment_Data_df['balance'].median(), inplace=True)

# As 'education', 'contact', and 'poutcome' already have 'unknown' values, we consider them as a category.

# 2. Handling categorical data: Check if conversion to numerical is needed
# For this dataset, we'll keep them as is for now since we can analyze them without conversion.

# Quick overview after cleaning
Assignment_Data_df.isnull().sum()  # Checking for remaining NaN values

# Let's also describe the dataset to understand its numerical features better.
Assignment_Data_df.describe()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25428\3606590017.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Assignment_Data_df['age'].fillna(Assignment_Data_df['age'].median(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_25428\3606590017.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the visualizations
sns.set_style("whitegrid")

# Visualization 1: Histogram of Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(Assignment_Data_df['age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Visualization 2: Average Account Balance by Job Category
plt.figure(figsize=(14, 8))
avg_balance_by_job = Assignment_Data_df.groupby('job')['balance'].mean().sort_values()
sns.barplot(x=avg_balance_by_job.values, y=avg_balance_by_job.index)
plt.title('Average Account Balance by Job')
plt.xlabel('Average Account Balance')
plt.ylabel('Job')

plt.tight_layout()
plt.show()

# %% [markdown]
# What is the distribution of account balances across different jobs?

# %%
# Visualization: Box Plot for Account Balance Distribution across Different Jobs

plt.figure(figsize=(16, 10))
sns.boxplot(x='job', y='balance', data=Assignment_Data_df)
plt.xticks(rotation=45)
plt.title('Distribution of Account Balances Across Different Jobs')
plt.xlabel('Job')
plt.ylabel('Account Balance')
plt.tight_layout()
plt.show()

# %% [markdown]
# How does marital status affect the loan status (having a personal loan)?

# %%
# Visualization: Marital Status vs. Loan Status

plt.figure(figsize=(10, 6))
sns.countplot(x='marital', hue='loan', data=Assignment_Data_df)
plt.title('Marital Status vs. Loan Status (Having a Personal Loan)')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Loan Status', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# What is the relationship between education level and the success of the campaign (y column)?

# %%
# Visualization: Education Level vs. Success of the Campaign

plt.figure(figsize=(10, 6))
sns.countplot(x='education', hue='y', data=Assignment_Data_df)
plt.title('Education Level vs. Success of the Campaign')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.legend(title='Campaign Outcome', labels=['No', 'Yes'], loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# How does the age distribution look among individuals with different educational backgrounds?

# %%
# Visualization: Age Distribution among Different Educational Backgrounds

plt.figure(figsize=(14, 8))
sns.violinplot(x='education', y='age', data=Assignment_Data_df)
plt.title('Age Distribution Among Individuals with Different Educational Backgrounds')
plt.xlabel('Education Level')
plt.ylabel('Age')
plt.tight_layout()
plt.show()
